# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, KFold, LeaveOneOut
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.metrics import recall_score, confusion_matrix, roc_curve, auc
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %%
from selenium import webdriver
url='https://www.imperva.com/cyber-threat-attack-map/'
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_argument("--disable-infobars")
path_to_chromedriver='C:\\Users\\nsrtk\\chromedriver_win32\\chromedriver.exe'
driver = webdriver.Chrome(executable_path = path_to_chromedriver,chrome_options=chrome_options)
driver.get(url)
# Out:
# C:\Users\nsrtk\AppData\Local\Temp/ipykernel_29656/1673104037.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path = path_to_chromedriver,chrome_options=chrome_options)
# C:\Users\nsrtk\AppData\Local\Temp/ipykernel_29656/1673104037.py:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path = path_to_chromedriver,chrome_options=chrome_options)
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29656/1673104037.py in <module>
#       6 chrome_options.add_argument("--disable-infobars")
#       7 path_to_chromedriver='C:\\Users\\nsrtk\\chromedriver_win32\\chromedriver.exe'
# ----> 8 driver = webdriver.Chrome(executable_path = path_to_chromedriver,chrome_options=chrome_options)
#       9 driver.get(url)
#      10
#
# ...

# %%
    import pandas as pd
    from datetime import datetime
    
    src_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[1]')
    target_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[2]')
    industry=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[3]')
    attack_type=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[4]')
    client=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[5]')
    no_of_requests=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[6]')
    
    l1=[]
    l3=[]
    l4=[]
    l5=[]
    l6=[]

    for x1 in src_countries:
        l1.append(x1.text)

    l2=[]
    for x2 in target_countries:
        #print(y.text)
        l2.append(x2.text)


    for x3 in industry:
        #print(x.text)
        l3.append(x3.text)

    for x4 in attack_type:
        #print(x.text)
        l4.append(x4.text)


    for x5 in client:
        #print(x.text)
        l5.append(x5.text)



    for x6 in no_of_requests:
        #print(x.text)
        l6.append(x6.text)

        
    

    # datetime object containing current date and time
    now = datetime.now()

    #print("now =", now)

    # dd/mm/YY H:M:S
    dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
    #print("date and time =", dt_string)
    #Data Frame
    df=pd.DataFrame({'Source Country':l1,'Destination Country':l2,'Industry':l3,'Type of Attack':l4,'Client':l5,'Number of requests':l6,"Date/Time":dt_string})
    print(df)
    
    
    #df.to_csv('D:\Directed Study Project\\file1.csv',mode='a',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29656/3721100020.py in <module>
#       2 from datetime import datetime
#       3
# ----> 4 src_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[1]')
#       5 target_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[2]')
#       6 industry=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[3]')
#
# NameError: name 'driver' is not defined

# %% [markdown]
# # Data Collection Part

# %%
import time
import pandas as pd
from datetime import datetime
from selenium.common import exceptions 
  
#boolean staleElement = True;
while(True):
    
    try:
       
        driver.get(url)
        src_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[1]')
        target_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[2]')
        industry=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[3]')
        attack_type=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[4]')
        client=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[5]')
        no_of_requests=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[6]')

        l1=[]
        l3=[]
        l4=[]
        l5=[]
        l6=[]

        for x1 in src_countries:
            l1.append(x1.text)

        l2=[]
        for x2 in target_countries:
            #print(y.text)
            l2.append(x2.text)


        for x3 in industry:
            #print(x.text)
            l3.append(x3.text)

        for x4 in attack_type:
            #print(x.text)
            l4.append(x4.text)


        for x5 in client:
            #print(x.text)
            l5.append(x5.text)



        for x6 in no_of_requests:
            #print(x.text)
            l6.append(x6.text)


        now = datetime.now()

        #print("now =", now)

        # dd/mm/YY H:M:S
        dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

        #Data Frame
        a={'Source Country':l1,'Destination Country':l2,'Industry':l3,'Type of Attack':l4,'Client':l5,'Number of requests':l6,"Date/Time":dt_string}
        #print(df)
        df = pd.DataFrame.from_dict(a, orient='index')
        df = df.transpose()
        df.to_csv('C:\\Users\\nsrtk\\file1.csv',mode='a',index=False,header=False)

        time.sleep(10)
        
       
    
    except exceptions.StaleElementReferenceException as e:
        #print(e)
        pass 
    #boolean staleElement = true;
# Out:
# C:\Users\nsrtk\AppData\Local\Temp/ipykernel_24600/3905616.py:12: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   src_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[1]')
# C:\Users\nsrtk\AppData\Local\Temp/ipykernel_24600/3905616.py:13: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   target_countries=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[2]')
# C:\Users\nsrtk\AppData\Local\Temp/ipykernel_24600/3905616.py:14: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   industry=driver.find_elements_by_xpath('//*[@id="root"]/div/div[1]/div[2]/div[2]/div[1]/table/tbody/tr/td[3]')
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
df=pd.read_csv("C:\\Users\\nsrtk\\file1.csv")
df
# Out:
#         Source_Country Destination_Country            Industry  \
# 0              Germany      Czech Republic      Computing & IT
# 1               Panama       United States    Food & Beverages
# 2              Ireland       United States              Sports
# 3        United States       United States             Society
# 4       United Kingdom               Chile            Gambling
# ...                ...                 ...                 ...
# 148595          Norway               Chile            Gambling
# 148596   United States              Brazil           Education
# 148597         Germany           Australia  Financial Services
# 148598          Russia       United States  Financial Services
# 148599   United States       United States  Financial Services
#
#                            Type_of_Attack              Client  \
# 0           OWASP - Protocol Manipulation       Vuln. Scanner
# 1                        Automated Threat        Hacking Tool
# ...
